# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
# !nvidia-smi
# Out:
# Mon Jul  5 17:18:24 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.27       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P0    24W / 300W |      0MiB / 16160MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# %cd "/content/drive/My Drive/Kaggle/Portrait/colab-sg2-ada/stylegan2-ada"
# Out:
# /content/drive/My Drive/Kaggle/Portrait/colab-sg2-ada/stylegan2-ada

# %%
# !python train.py --outdir='/content/drive/MyDrive/Kaggle/Portrait/Results' --snap=5  --data='/content/drive/MyDrive/Kaggle/Portrait/Dataset' --augpipe='bg' --mirror=True  --mirrory=False --metrics=None --resume='ffhq512'
# Out:
# tcmalloc: large alloc 4294967296 bytes == 0x55bef7846000 @  0x7fa78ab03001 0x7fa787d0654f 0x7fa787d56b58 0x7fa787d5ab17 0x7fa787df9203 0x55beef2bad54 0x55beef2baa50 0x55beef32f105 0x55beef3297ad 0x55beef2bcc9f 0x55beef2fdd79 0x55beef2facc4 0x55beef2bb559 0x55beef32f4f8 0x55beef3294ae 0x55beef1fbe2c 0x55beef32bbb5 0x55beef3294ae 0x55beef1fbe2c 0x55beef32bbb5 0x55beef3297ad 0x55beef1fbe2c 0x55beef32bbb5 0x55beef2bc30a 0x55beef32a3b5 0x55beef3294ae 0x55beef3291b3 0x55beef3f3182 0x55beef3f34fd 0x55beef3f33a6 0x55beef3ca723
# ...
